# %% [markdown]
# ### Socratic API
#
# We can also access the NTD Annual Fuel and Energy data using a free API endpoint with _unlimited_ usage, as long as we are using an [application token](https://dev.socrata.com/docs/app-tokens). We can query this data using this endpoint, https://data.transportation.gov/resource/8ehq-7his.json, and we can filter the data using [SoQL clauses](https://dev.socrata.com/docs/queries/).

# %%
# Requires requests, pip install requests
import requests
import json

# Define querying function
def query_ntd(params):
    url = "https://data.transportation.gov/resource/8ehq-7his.json"
    response = requests.get(url, params=params)
    # print(response.url)
    if response.status_code == 200:
        data = response.json()
        print(json.dumps(data, indent=2))
    else:
        print(f"Request failed with status code {response.status_code}")

# Define our SoQL clauses
basic_params = {
    '$select': 'distinct city',
    '$where': 'state="NY"',
    '$order': 'city'
}

# Query API w/ our basic clauses
query_ntd(basic_params)
# Out:
# /Users/lgrassi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [
#   {
#     "city": "Albany"
#   },
#   {
#     "city": "Binghamton"
#   },
#   {
#     "city": "Brooklyn"
#   },
#   {
#     "city": "Buffalo"
#   },
#   {
#     "city": "Calverton"
#   },
#   {
#     "city": "Carmel"
#   },
#   {
#     "city": "Huntington"
#   },
#   {
#     "city": "Hurley"
#   },
#   {
#     "city": "Ithaca"
#   },
#   {
#     "city": "Jamaica"
#   },
#   {
#     "city": "Kingston"
#   },
#   {
#     "city": "Long Beach"
#   },
#   {
#     "city": "Mineola"
#   },
#   {
#     "city": "New City"
#   },
#   {
#     "city": "New York"
#   },
#   {
#     "city": "Poughkeepsie"
#   },
#   {
#     "city": "Rochester"
#   },
#   {
#     "city": "Spring Valley"
#   },
#   {
#     "city": "Staten Island"
#   },
#   {
#     "city": "Syracuse"
#   },
#   {
#     "city": "White Plains"
#   },
#   {
#     "city": "Yaphank"
#   }
# ]

# %% [markdown]
# ### Gathering data by UACE codes
#
# To find the different column id's that correspond to each column, visit [this](https://data.transportation.gov/Public-Transit/2022-NTD-Annual-Data-Fuel-and-Energy/8ehq-7his/data) website, click **Export**, then **SODA API**, and all of the column id's will be listed below.

# %%
def get_data_about_uace(code, select_vals):
    select_params = ",".join(select_vals)
    params = {
        '$select': select_params,
        '$where': 'uace_code="' + code +'"'
    }
    query_ntd(params)
    
get_data_about_uace('63217', ["uace_code","agency","city","gasoline_gal","diesel_gal","gasoline","diesel"])
# Out:
# [
#   {
#     "uace_code": "63217",
#     "agency": "MTA New York City Transit",
#     "city": "Brooklyn",
#     "gasoline_gal": "0",
#     "diesel_gal": "3697741",
#     "gasoline": "0",
#     "diesel": "15739148"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "MTA New York City Transit",
#     "city": "Brooklyn",
#     "gasoline_gal": "0",
#     "diesel_gal": "23170009",
#     "gasoline": "0",
#     "diesel": "79941725"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "MTA New York City Transit",
#     "city": "Brooklyn",
#     "gasoline_gal": "3570980",
#     "diesel_gal": "19738",
#     "gasoline": "28059319",
#     "diesel": "242940"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "MTA New York City Transit",
#     "city": "Brooklyn",
#     "gasoline_gal": "0",
#     "diesel_gal": "1070814",
#     "gasoline": "0",
#     "diesel": "3180905"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "MTA New York City Transit",
#     "city": "Brooklyn",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New Jersey Transit Corporation",
#     "city": "Newark",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New Jersey Transit Corporation",
#     "city": "Newark",
#     "gasoline_gal": "0",
#     "diesel_gal": "14018352",
#     "gasoline": "0",
#     "diesel": "2749033"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New Jersey Transit Corporation",
#     "city": "Newark",
#     "gasoline_gal": "0",
#     "diesel_gal": "667776",
#     "gasoline": "0",
#     "diesel": "1211272"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New Jersey Transit Corporation",
#     "city": "Newark",
#     "gasoline_gal": "0",
#     "diesel_gal": "1887499",
#     "gasoline": "0",
#     "diesel": "8189868"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New Jersey Transit Corporation",
#     "city": "Newark",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New Jersey Transit Corporation",
#     "city": "Newark",
#     "gasoline_gal": "1761034",
#     "diesel_gal": "0",
#     "gasoline": "16052645",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New Jersey Transit Corporation",
#     "city": "Newark",
#     "gasoline_gal": "44867",
#     "diesel_gal": "0",
#     "gasoline": "765035",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New Jersey Transit Corporation",
#     "city": "Newark",
#     "gasoline_gal": "0",
#     "diesel_gal": "19011620",
#     "gasoline": "0",
#     "diesel": "83395816"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Metro-North Commuter Railroad Company, dba: MTA Metro-North Railroad",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "192849",
#     "gasoline": "0",
#     "diesel": "46140"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Metro-North Commuter Railroad Company, dba: MTA Metro-North Railroad",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "41741",
#     "gasoline": "0",
#     "diesel": "205598"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Metro-North Commuter Railroad Company, dba: MTA Metro-North Railroad",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "6882694",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "MTA Bus Company",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "9476906",
#     "gasoline": "0",
#     "diesel": "23116558"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "MTA Long Island Rail Road",
#     "city": "Jamaica",
#     "gasoline_gal": "0",
#     "diesel_gal": "7310132",
#     "gasoline": "0",
#     "diesel": "982180"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Westchester County, dba: The Bee-Line System",
#     "city": "White Plains",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Westchester County, dba: The Bee-Line System",
#     "city": "White Plains",
#     "gasoline_gal": "0",
#     "diesel_gal": "2333427",
#     "gasoline": "0",
#     "diesel": "7571675"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Westchester County, dba: The Bee-Line System",
#     "city": "White Plains",
#     "gasoline_gal": "288382",
#     "diesel_gal": "0",
#     "gasoline": "2981008",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "County of Nassau, dba: Nassau Inter County Express",
#     "city": "Mineola",
#     "gasoline_gal": "10905",
#     "diesel_gal": "6790",
#     "gasoline": "63972",
#     "diesel": "69461"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "County of Nassau, dba: Nassau Inter County Express",
#     "city": "Mineola",
#     "gasoline_gal": "220732",
#     "diesel_gal": "26552",
#     "gasoline": "1470302",
#     "diesel": "332839"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Port Authority Trans-Hudson Corporation",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Suffolk County , dba: Dept of Public Works - Transportation Division",
#     "city": "Yaphank",
#     "gasoline_gal": "1147047",
#     "diesel_gal": "0",
#     "gasoline": "9037388",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Suffolk County , dba: Dept of Public Works - Transportation Division",
#     "city": "Yaphank",
#     "gasoline_gal": "231609",
#     "diesel_gal": "1084223",
#     "gasoline": "4241833",
#     "diesel": "3735629"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Academy Lines, Inc.",
#     "city": "Hoboken",
#     "gasoline_gal": "0",
#     "diesel_gal": "668954",
#     "gasoline": "0",
#     "diesel": "3177531"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Hudson Transit Lines, Inc.",
#     "city": "Mahwah",
#     "gasoline_gal": "0",
#     "diesel_gal": "944587",
#     "gasoline": "0",
#     "diesel": "5598476"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Somerset County, dba: Somerset County Transportation",
#     "city": "Somerville",
#     "gasoline_gal": "64415",
#     "diesel_gal": "21287",
#     "gasoline": "181158",
#     "diesel": "137884"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Somerset County, dba: Somerset County Transportation",
#     "city": "Somerville",
#     "gasoline_gal": "102160",
#     "diesel_gal": "0",
#     "gasoline": "773482",
#     "diesel": "9783"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Hampton Jitney, Inc.",
#     "city": "Calverton",
#     "gasoline_gal": "0",
#     "diesel_gal": "428924",
#     "gasoline": "0",
#     "diesel": "3060141"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "County of Rockland , dba: Public Transportation - Transport of Rockland",
#     "city": "New City",
#     "gasoline_gal": "16744",
#     "diesel_gal": "391733",
#     "gasoline": "105512",
#     "diesel": "1920049"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "County of Rockland , dba: Public Transportation - Transport of Rockland",
#     "city": "New City",
#     "gasoline_gal": "70126",
#     "diesel_gal": "0",
#     "gasoline": "589713",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Bergen County, dba: Bergen County Community Transportation",
#     "city": "Hackensack",
#     "gasoline_gal": "9531",
#     "diesel_gal": "0",
#     "gasoline": "67360",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Bergen County, dba: Bergen County Community Transportation",
#     "city": "Hackensack",
#     "gasoline_gal": "79229",
#     "diesel_gal": "0",
#     "gasoline": "559956",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Staten Island Rapid Transit Operating Authority, dba:  MTA Staten Island Railway",
#     "city": "Staten Island",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Port Imperial Ferry Corporation, dba: NY Waterway",
#     "city": "Weehawken",
#     "gasoline_gal": "0",
#     "diesel_gal": "1908884",
#     "gasoline": "0",
#     "diesel": "444326"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Port Imperial Ferry Corporation, dba: NY Waterway",
#     "city": "Weehawken",
#     "gasoline_gal": "0",
#     "diesel_gal": "99043",
#     "gasoline": "0",
#     "diesel": "253908"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Lakeland Bus Lines, Inc.",
#     "city": "Dover",
#     "gasoline_gal": "0",
#     "diesel_gal": "293079",
#     "gasoline": "0",
#     "diesel": "1011075"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Orange-Newark-Elizabeth, Inc.",
#     "city": "Elizabeth",
#     "gasoline_gal": "0",
#     "diesel_gal": "221969",
#     "gasoline": "0",
#     "diesel": "903976"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Suburban Transit Corporation",
#     "city": "New Brunswick",
#     "gasoline_gal": "0",
#     "diesel_gal": "772193",
#     "gasoline": "0",
#     "diesel": "2921910"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Rockland Coaches, Inc.",
#     "city": "Westwood",
#     "gasoline_gal": "0",
#     "diesel_gal": "283362",
#     "gasoline": "0",
#     "diesel": "1563294"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Monsey New Square Trails Corporation",
#     "city": "Spring Valley",
#     "gasoline_gal": "0",
#     "diesel_gal": "288710",
#     "gasoline": "0",
#     "diesel": "841455"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New York City Economic Development Corporation",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "3856180",
#     "gasoline": "0",
#     "diesel": "1001425"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New York City Economic Development Corporation",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "18749",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Town of Huntington, dba: Huntington Area Rapid Transit",
#     "city": "Huntington",
#     "gasoline_gal": "27755",
#     "diesel_gal": "0",
#     "gasoline": "955510",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Town of Huntington, dba: Huntington Area Rapid Transit",
#     "city": "Huntington",
#     "gasoline_gal": "33156",
#     "diesel_gal": "21033",
#     "gasoline": "0",
#     "diesel": "175840"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Trans-Bridge Lines, Inc.",
#     "city": "Bethlehem",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "1269214"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "DeCamp Bus Lines",
#     "city": "Montclair",
#     "gasoline_gal": "0",
#     "diesel_gal": "214773",
#     "gasoline": "0",
#     "diesel": "1059444"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New York City Department of Transportation",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "4840205",
#     "gasoline": "0",
#     "diesel": "192239"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Adirondack Transit Lines, Inc,",
#     "city": "Hurley",
#     "gasoline_gal": "0",
#     "diesel_gal": "217501",
#     "gasoline": "0",
#     "diesel": "3239304"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Putnam County , dba: Putnam Area Rapid Transit",
#     "city": "Carmel",
#     "gasoline_gal": "14008",
#     "diesel_gal": "0",
#     "gasoline": "116070",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "New York City Department of Transportation",
#     "city": "New York",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Putnam County , dba: Putnam Area Rapid Transit",
#     "city": "Carmel",
#     "gasoline_gal": "57495",
#     "diesel_gal": "0",
#     "gasoline": "407759",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "City of Long Beach",
#     "city": "Long Beach",
#     "gasoline_gal": "804",
#     "diesel_gal": "0",
#     "gasoline": "9786",
#     "diesel": "0"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "SeaStreak, LLC",
#     "city": "Atlantic Highlands",
#     "gasoline_gal": "0",
#     "diesel_gal": "1701973",
#     "gasoline": "0",
#     "diesel": "144634"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "City of Long Beach",
#     "city": "Long Beach",
#     "gasoline_gal": "0",
#     "diesel_gal": "56078",
#     "gasoline": "0",
#     "diesel": "235526"
#   },
#   {
#     "uace_code": "63217",
#     "agency": "Private Transportation Corporation",
#     "city": "Brooklyn",
#     "gasoline_gal": "0",
#     "diesel_gal": "0",
#     "gasoline": "0",
#     "diesel": "0"
#   }
# ]

# %% [markdown]
# ### Aggregate data manipulation
#
# Using SoQL allows us to do some powerful data aggregation using `$group` and specific clauses found [here](https://dev.socrata.com/docs/queries/group).

# %%
gasoline_info_params = {
    '$select': 'uace_code,SUM(gasoline_gal) as total_gas_gals,SUM(gasoline) as total_gas_miles,AVG(gasoline) as avg_gas_miles',
    '$where': 'uace_code="63217"',
    '$group': 'uace_code'
}

print("\nInformation about gasoline usage in UACE 63217")
query_ntd(gasoline_info_params)

ranked_params = {
    "$select": "uace_code, SUM(gasoline_gal) as total_gas_gals",
    "$group": "uace_code",
    "$order": "SUM(gasoline_gal) DESC",
    "$limit": "10"
}

print("\nTop 10 UACE codes in terms of gallons of gas used")
query_ntd(ranked_params)
# Out:
# Information about gasoline usage in UACE 63217
# [
#   {
#     "uace_code": "63217",
#     "total_gas_gals": "7750979",
#     "total_gas_miles": "66437808",
#     "avg_gas_miles": "1145479.448275862069"
#   }
# ]
#
# Top 10 UACE codes in terms of gallons of gas used
# [
#   {
#     "uace_code": "63217",
#     "total_gas_gals": "7750979"
#   },
#   {
#     "uace_code": "51445",
#     "total_gas_gals": "5235725"
#   },
#   {
#     "uace_code": "57628",
#     "total_gas_gals": "4400701"
#   },
#   {
#     "uace_code": "16264",
#     "total_gas_gals": "3134130"
#   },
#   {
#     "uace_code": "56602",
#     "total_gas_gals": "3069851"
#   },
#   {
#     "uace_code": "40429",
#     "total_gas_gals": "2705990"
#   },
#   {
#     "uace_code": "92242",
#     "total_gas_gals": "2421185"
#   },
#   {
#     "uace_code": "80389",
#     "total_gas_gals": "1871475"
#   },
#   {
#     "uace_code": "4843",
#     "total_gas_gals": "1816826"
#   },
#   {
#     "uace_code": "78904",
#     "total_gas_gals": "1658109"
#   }
# ]
